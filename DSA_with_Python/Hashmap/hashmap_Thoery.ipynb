# %% [markdown]
# # 📘 Hashmaps (Hashtable) – Complete Notes
#
# Author: Musharraf Bubere
# Repository: Learning-in-public
# Topic: Data Structures & Algorithms

# %% [markdown]
# ## 1️⃣ What is a HashMap?
#
# A **HashMap (also called Hashtable)** is a data structure that stores data in **key–value pairs**.
#
# It allows:
# - Fast insertion
# - Fast deletion
# - Fast searching
#
# HashMaps use a technique called **Hashing**.
#
# ### 🔹 Core Idea
# A key is converted into an integer index using a **hash function**, which allows accessing data in constant time.
#
# ⏱ Average Time Complexity: **O(1)**

# %% [markdown]
# ## 2️⃣ Real World Examples
#
# ### Practical Examples
# - 📖 Dictionary → Word → Meaning
# - 📱 Phone Contacts → Name → Number
# - 🆔 Student ID → Student Data
#
# ### Technical Examples
# - 🔍 DNS lookup
# - 💾 SQL Databases
# - 🌐 Web caching
# - 🧠 Compiler Symbol Table

# %% [markdown]
# ## 3️⃣ Why Hashing?
#
# ### Problem:
# Find the highest occurring character in a string.
#
# ### ❌ Sorting Approach
# Time Complexity → O(n log n)
#
# ### ✅ HashMap Approach
# Time Complexity → O(n)
#
# We store frequency in a dictionary.
#
# Hashing avoids unnecessary sorting and improves efficiency.

# %% [markdown]
# ## 4️⃣ Basic Operations in HashMap
#
# | Operation | Description |
# |-----------|------------|
# | Insert | Add or update key-value |
# | Search | Retrieve value using key |
# | Delete | Remove key-value |
#
# Average Complexity: **O(1)**

# %% [markdown]
# ## 5️⃣ Hash Function
#
# A **hash function** converts a key into an integer index.
#
# ### Step 1:
# Convert key → integer
#
# Example:
# "abc" → ASCII values → number
#
# ### Step 2:
# Compress into valid index
#
# index = hash_value % size
#
# This ensures index stays within bucket size.

# %% [markdown]
# ## 6️⃣ Collision
#
# A collision happens when:
#
# Two different keys produce the same index.
#
# Example:
#
# 50 % 5 = 0
# 80 % 5 = 0
#
# Both go to index 0 → Collision

# %% [markdown]
# ## 7️⃣ Collision Handling Techniques
#
# ### 🔹 1. Open Addressing
#
# If index is occupied, search for next empty slot.
#
# - Linear Probing
# - Quadratic Probing
# - Double Hashing
#
# ---
#
# ### 🔹 2. Chaining
#
# Each bucket stores a linked list.
#
# If collision occurs:
# Insert new element into linked list.

# %% [markdown]
# ## 8️⃣ Load Factor
#
# Load Factor (α):
#
# α = n / b
#
# Where:
# - n = number of elements
# - b = bucket size
#
# If α increases → collisions increase.
#
# Best Practice:
# Keep α ≤ 0.75

# %% [markdown]
# ## 9️⃣ Rehashing
#
# When load factor exceeds threshold:
#
# Steps:
# 1. Save old buckets
# 2. Double capacity
# 3. Create new bucket array
# 4. Reinsert all elements
#
# Rehashing Time: O(n)
# Amortized Complexity: O(1)

# %% [markdown]
# ## 🔟 HashMap in Python
#
# Python dictionary is implemented using HashMap.

# %% [markdown]
# # Basic HashMap Example in Python
#
# d = {}
#
# # Insert
# d["apple"] = 10
# d["banana"] = 20
#
# # Search
# print("Apple value:", d["apple"])
#
# # Update
# d["apple"] = 100
#
# # Delete
# del d["banana"]
#
# print(d)

# %% [markdown]
# ---
#
# ## 📊 Time Complexity Summary
#
# | Operation | Average | Worst |
# |-----------|---------|-------|
# | Insert | O(1) | O(n) |
# | Search | O(1) | O(n) |
# | Delete | O(1) | O(n) |
#
# ---
#
# ## 🚀 Key Takeaways
#
# - HashMap provides constant time access.
# - Collisions are unavoidable.
# - Chaining and Probing solve collisions.
# - Load factor controls efficiency.
# - Rehashing maintains performance.
