# %% [markdown]
# # 1. Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# # 2. Opening a Local csv file

# %%
df = pd.read_csv('aug_train.csv')
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # 3. Opening a csv file from an URL

# %%
import requests
from io import StringIO

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefoz/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # 4. Sep Parameter

# %%
pd.read_csv('movie_titles_metadata.tsv', sep='\t', names=['sno', 'name', 'release_year', 'rating', 'votes', 'genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# # 5. Index_col Parameter

# %%
pd.read_csv('aug_train.csv', index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# # 6. Header Parameter

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/test.csv', header=1)
# Out:
#              0  B B.1 B.2  C B.3 B.4  A  E E.1  ... 0.4767390451101133  \
# 0            5  A   B   A  C   B   C  A  E   C  ...           0.285509
# 1           15  B   A   A  A   B   B  A  E   D  ...           0.697272
# 2           16  B   B   A  C   B   D  A  E   A  ...           0.719306
# 3           17  B   B   A  C   B   C  A  E   C  ...           0.313032
# 4           19  B   B   B  C   B   B  A  E   E  ...           0.489711
# ...        ... ..  ..  .. ..  ..  .. .. ..  ..  ...                ...
# 199994  499987  B   A   A  C   B   D  A  E   E  ...           0.287454
# 199995  499990  B   A   A  C   B   B  A  E   C  ...           0.794881
# 199996  499991  A   B   B  C   B   B  A  E   C  ...           0.514487
# 199997  499994  A   A   A  C   B   D  A  D   A  ...           0.286144
# 199998  499995  A   A   A  C   B   D  A  E   A  ...           0.286755
#
#         0.37634964704960105  0.3378838967546349  0.3218317548420124  \
# ...

# %% [markdown]
# # 7. use_cols parameter

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', usecols=['enrollee_id', 'gender', 'education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# # 8. Squeeze parameters

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', usecols=['enrollee_id'], squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', usecols=['enrollee_id'], squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %% [markdown]
# # 9. Skiprows/nrows parameter

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', skiprows=[0,2])
# Out:
#         8949  city_103   0.92  Male  Has relevent experience  \
# 0      11561   city_21  0.624   NaN   No relevent experience
# 1      33241  city_115  0.789   NaN   No relevent experience
# 2        666  city_162  0.767  Male  Has relevent experience
# 3      21651  city_176  0.764   NaN  Has relevent experience
# 4      28806  city_160  0.920  Male  Has relevent experience
# ...      ...       ...    ...   ...                      ...
# 19151   7386  city_173  0.878  Male   No relevent experience
# 19152  31398  city_103  0.920  Male  Has relevent experience
# 19153  24576  city_103  0.920  Male  Has relevent experience
# 19154   5756   city_65  0.802  Male  Has relevent experience
# 19155  23834   city_67  0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM  >20 Unnamed: 9  \
# 0      Full time course        Graduate             STEM    5        NaN
# 1                   NaN        Graduate  Business Degree   <1        NaN
# ...

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', nrows=100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# # 10. Encoding parameter

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/zomato.csv', encoding='latin-1')
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# # 11. Skip badlines

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/BX-Books.csv', sep=';', encoding='latin-1', error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/BX-Books.csv', sep=';', encoding='latin-1', error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'. Did you mean 'on_bad_lines'?

# %% [markdown]
# # 12. dtypes parameter

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', dtype={'target': int}).info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  str
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  str
#  4   relevent_experience     19158 non-null  str
#  5   enrolled_university     18772 non-null  str
#  6   education_level         18698 non-null  str
#  7   major_discipline        16345 non-null  str
#  8   experience              19093 non-null  str
#  9   company_size            13220 non-null  str
#  10  company_type            13018 non-null  str
#  11  last_new_job            18735 non-null  str
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# dtypes: float64(1), int64(3), str(10)
# memory usage: 2.0 MB

# %% [markdown]
# # 13. Handling Dates

# %%
pd.read_csv(r'D:\Learning-In-Public\Machine-Learning\Practical_Implementation\data\matches.csv', parse_dates=['date']).info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   str
#  2   city             1044 non-null   str
#  3   date             1095 non-null   datetime64[us]
#  4   match_type       1095 non-null   str
#  5   player_of_match  1090 non-null   str
#  6   venue            1095 non-null   str
#  7   team1            1095 non-null   str
#  8   team2            1095 non-null   str
#  9   toss_winner      1095 non-null   str
#  10  toss_decision    1095 non-null   str
#  11  winner           1090 non-null   str
#  12  result           1095 non-null   str
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   str
# ...

# %% [markdown]
# # 14. Convertors

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name
    
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
pd.read_csv(r'D:\Learning-In-Public\Machine-Learning\Practical_Implementation\data\matches.csv', converters={'team1': rename})
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %% [markdown]
# # 15. na_values parameter

# %%
pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # 16. Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('D:/Learning-In-Public/Machine-Learning/Practical_Implementation/data/aug_train.csv', chunksize=5000)

# %%
for chunk in dfs:
    print(chunk.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
