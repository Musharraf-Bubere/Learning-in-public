# %% [markdown]
# ### 📘 Scalars and Vectors (Linear Algebra Basics)
#
# ![Scalars and Vectors](images/Scalar_And_Vectors_Page_1.png)
#
# ---
#
# ## 🔹 Introduction
#
# Scalars and vectors are **fundamental building blocks** used in:
#
# - **Physics**
# - **Mathematics**
# - **Computer Science**
# - **Data Science & Machine Learning**
#
# They are used to represent **data, features, directions, and magnitudes**.
#
# ---
#
# ## 🔸 1. Scalar
#
# ### ✅ Definition
# A **scalar** is a **single numerical value** that represents **only magnitude** and **has no direction**.
#
# ---
#
# ### 📌 Examples of Scalars
#
# - 🚗 Car speed = **45 km/h**
# - 🌡 Temperature = **30°C**
# - 🎂 Age = **25 years**
# - 📊 Count of records in a dataset
#
# ---
#
# ### 📊 Scalars in Data Science
#
# - Mean of a feature
# - Count of observations
# - Bias term in Linear Regression
# - Intercept in equation:
# \[
# y = mx + c
# \]
#
# Here:
# - \(m\) (slope) → scalar
# - \(c\) (intercept) → scalar
#
# ---
#
# ## 🔸 2. Vector
#
# ![Vector Representation](images/Scalar_And_Vectors_Page_2.png)
#
# ### ✅ Definition
# A **vector** is a numerical quantity that has:
#
# - **Magnitude**
# - **Direction**
#
# It is usually represented as an **ordered list of numbers**.
#
# ---
#
# ### 📌 Examples of Vectors
#
# - 🚗 Speed + Direction → **45 km/h East**
# - 📍 Position in space → \((x, y)\)
# - 🧠 Feature vector in ML → \([IQ, study\_hours]\)
#
# Example:
# \[
# [90,\ 3]
# \]
# ( IQ = 90, Study Hours = 3 )
#
# ---
#
# ### 📊 Vectors in Data Science
#
# - Feature vectors
# - Weight vectors
# - Input to ML models
#
# Example:
# \[
# X = [f_1, f_2, f_3]
# \]
#
# ---
#
# ## 🔸 Vector Dimensions
#
# - \([1, 2]\) → **2D vector**
# - \([70, 72, 75, 73]\) → **4D vector**
# - \([x, y, z]\) → **3D vector**
#
# More features = **higher dimension**
#
# ---
#
# ## 🔸 Unit Vector
#
# A **unit vector** has a magnitude of **1**.
#
# \[
# \|\hat{v}\| = 1
# \]
#
# - Direction only
# - Used in **normalization**
# - Important in **ML optimization**
#
# ---
#
# ## 🔸 Scalars vs Vectors (Quick Comparison)
#
# | Feature | Scalar | Vector |
# |------|------|------|
# | Value | Single number | List of numbers |
# | Direction | ❌ No | ✅ Yes |
# | Example | Temperature | Velocity |
# | ML Usage | Bias | Features |
#
# ---
#
# ## 🔸 Application Example (ML Perspective)
#
# ![Applications](images/Scalar_And_Vectors_Page_3.png)
#
# ### 🎯 House Price Dataset
#
# | Feature | Type |
# |------|------|
# | Size | Continuous → Vector |
# | Rooms | Discrete → Vector |
# | Location | Categorical → Vector |
# | Price | Continuous → Scalar |
#
# ---
#
# ## 🔑 Key Takeaways
#
# - Scalars represent **magnitude only**
# - Vectors represent **magnitude + direction**
# - Machine Learning models operate on **vectors**
# - Scalars are often **outputs or parameters**
# - Understanding vectors is crucial for **Linear Algebra, ML, DL**
#
# ---
#
# 📌 **Next Topic:**
# Vector operations (Addition, Dot Product, Magnitude, Projection)
