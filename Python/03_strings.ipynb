# %% [markdown]
# Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Function

# %%
# Creating Strings

s1 = 'hello'
s2 = "hello"

# for multiline strings
s3 = '''hello'''
s4 = """hello"""

s5 = str("hello")

print(s1)
print(s2)
print(s3)
print(s4)
print(s5)
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
"it's raining outside"
# Out:
# "it's raining outside"

# %% [markdown]
# ### Accessing substrings from a string

# %%
# Positive Indexing
s = "hello world"
print(s[2])
# Out:
# l

# %%
# Negative Indexing
s = "hello world"
print(s[-1])
# Out:
# d

# %%
# Slicing
s = "hello world"
print(s[0:5])
# Out:
# hello

# %%
print(s[::-1])
# Out:
# dlrow olleh

# %%
s = "hello world"
print(s[-5:])
# Out:
# world

# %%
s = 'hello world'
s[0] = 'H'

# Python strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 s = 'hello world'
# ----> 2 s[0] = 'H'
#       3
#       4 # Python strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'hello world'
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 s = 'hello world'
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %%
s = 'hello world'
del s[-1:-5:2]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 s = 'hello world'
# ----> 2 del s[-1:-5:2]
#       3 print(s)
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# ### Operations on Strings
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
print('delhi' + ' ' + 'mumbai')
# Out:
# delhi mumbai

# %%
print('delhi'*5)
# Out:
# delhidelhidelhidelhidelhi

# %%
'delhi' == 'delhi'
# Out:
# True

# %%
'mumbai' > 'pune'
# lexiopraphically
# Out:
# False

# %%
'Pune' > 'pune'
# Out:
# False

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
'' and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
not 'hello'
# Out:
# False

# %%
for i in 'hello':
    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
for i in 'delhi':
    print('pune')
# Out:
# pune
# pune
# pune
# pune
# pune

# %%
'D' in 'Delhi'
# Out:
# True

# %%
'D' not in 'delhi'
# Out:
# True

# %% [markdown]
# ### Common Functions
# - len
# - max
# - min
# - sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello world', reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# captatize/Title/upper/lower/swapcase

# %%
s = 'hello world'
s.capitalize()
# Out:
# 'Hello world'

# %%
s = 'hello world'
s.title()
# Out:
# 'Hello World'

# %%
s = 'hello world'
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s = 'hello world'
s.lower()
# Out:
# 'hello world'

# %%
s = 'hello world'
s.swapcase()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# count/find/index

# %%
'my name is musharraf'.count('i')
# Out:
# 1

# %%
'my name is musharraf'.find('musharraf')
# Out:
# 11

# %%
'my name is musharraf'.index('is')
# Out:
# 8

# %% [markdown]
# endswith/startwith

# %%
'my name is musharraf'.endswith('af')
# Out:
# True

# %%
'my name is musharraf'.startswith('is')
# Out:
# False

# %% [markdown]
# format

# %%
name = 'musharraf'
gender = 'male'

'Hi my name is {} and I am a {}'.format(name,gender)
# Out:
# 'Hi my name is musharraf and I am a male'

# %% [markdown]
# isalnum/isalpha/isdigit/isidentifier

# %%
'musharraf123@'.isalnum()
# Out:
# False

# %%
'musharaf'.isalpha()
# Out:
# True

# %%
'123'.isdigit()
# Out:
# True

# %%
'1mushar'.isidentifier()
# Out:
# False

# %% [markdown]
# split/join

# %%
'hi my name musharraf'.split('a')
# Out:
# ['hi my n', 'me mush', 'rr', 'f']

# %%
''.join(['hi my n', 'me mush', 'rr', 'f'])
# Out:
# 'hi my nme mushrrf'

# %% [markdown]
# Replace

# %%
'hi my name is musharraf'.replace('musharraf','bubere')
# Out:
# 'hi my name is bubere'

# %% [markdown]
# strip

# %%
s = '   musharraf   '
s.strip()
# Out:
# 'musharraf'

# %% [markdown]
# # Example Programs

# %%
# Find the length of a given string without using the len() function
s = input('Enter the string:')

counter = 0

for i in s:
    counter += 1

print('Length of string is',counter)
# Out:
# Length of string is 8

# %%
# Extract username from a given email.
# E.g.  if the email is nitish24singh@gmail.com
# then the username shoulb be nitish24singh

s = input("Enter the email:")

pos = s.index('@')
print(s[0:pos])
# Out:
# musharaf

# %%
# Count the frequency of a particular character in a provided string.
# eg. 'hello how are you' is the string, the frequency of h in this string is 2.

s = input("Enter the string:")
term = input("Enter what would like to search for:")

counter = 0

for i in s:
    if i == term:
        counter += 1
print('Frequency', counter)
# Out:
# Frequency 2

# %%
# Write a program which can remove a particular character from a string.
s = input("Enter the string:")
term = input("Enter what would like to remove:")

result = ''

for i in s:
    if i != term:
        result = result + i

print(result)
# Out:
# usharraf

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam
# madam

s = input("Enter the string:")
flag = True

for i in range(0,len(s)//2):
    if s[i] != s[len(s)-i -1]:
        flag = False
        print('Not a Palindrome')
        break

if flag:
    print('Palindrome')
# Out:
# Not a Palindrome

# %%
# Write a program to count the number of words in a string without split()

s = input("Enter the string:")
l = []
temp = ''
for i in s:
    if i != ' ':
        temp = temp + i
    else:
        l.append(temp)
        temp = ''
l.append(temp)
print(len(l))
# Out:
# 8

# %%
# Write a python program to convert a string to title case without using title()

s = input("Enter the string:")
l = []

for i in s.split():
    l.append(i[0].upper() + i[1:].lower())

print(" ".join(l))
# Out:
# Hi How Are Yoy

# %%
# Write a program that can convert an integer to string without using str()

number = int(input("Enter the number:"))
digits = '0123456789'
result = ''

while number != 0:
    result = digits[number % 10] + result
    number = number // 10
print(result)
print(type(result))
# Out:
# 1235
# <class 'str'>
