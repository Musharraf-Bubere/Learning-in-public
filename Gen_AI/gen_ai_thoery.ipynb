# %% [markdown]
# # GenAI

# %% [markdown]
# ### What is GenAI?
#
# Generative AI is a type of aritificial intelligence that creates new content - such as text, images, music, or code - by learning patterns from existing data, mimicking human creativity.
#
#
# AI --> ML --> DL --> GenAI
#
# ### GenAI Impact Areas
#
# 1. Customer Support
# 2. Content Creation
# 3. Education
# 4. Software Development
#
#
# ### Is GenAI Successful Technology?
#
# 1. Does it solve real world problems? # Yes
# 2. Is it useful on a daily basis? # Yes
# 3. Is it impacting the world economics? # Yes
# 4. Is it creating new jobs? # Yes
# 5. Is it accessible? # Yes
#
#
# ### Why not?
#
# 1. I had doubts
# 2. Time commitment
# 3. It was intimidating
#
#
# ### The Problem
#
# 1. very fast progress
# 2. the FOMO merchants
# 3. No single source to learn
#
#
# ### Solution => Mental Model
#
# Foundation Models = Generalized Models --> LLMs, LMMs ==> On Centered
# - User Perspective
# - Builder Perspective
#
#
# ### And the game began!
#
# Prompt Engineering ---> User Perspective
#
# RLHF (Reinforcement Learning with the Help of human Feedback) ---> Builder Perspective
#
# RAG ---> User Perspective
#
# Pretraining ---> Builder Perspective
#
# Quantization ---> Builder Perspective
#
# AI Agents ---> User Perspective
#
# Vector Databases ---> User Perspective
#
# Fine Tuning ---> User Perspective and Builder Perespective
#
#
# ### The Builder's Perspective
#
# STEPS:
# 1. Transformer Architecture
# 2. Types of Transformers (Encoder Only (BERT), Decoder Only (GPT), Encoder & Decoder based (T5))
# 3. Pretraining (Training objectives, Tokenization Strategies, Training Strategies, Handling Challenges)
# 4. Optimization (Training Optimization, Model Compression, Optimizing Inference)
# 5. Fine Tuning (Task Specific Tuning (RLHF), Instruction Tuning (PEFT), Continual Pretraining)
# 6. Evaluation
# 7. Deployment
#
#
# ### The User's Perspective
#
# STEPS:
# 1. Building Basic LLM Apps (Open Source vs Closed Source LLMs, Using LLM APIs, LangChain, HuggingFace, Ollama)
# 2. Prompt Engineering
# 3. RAG
# 4. Fine Tuning
# 5. Agents
# 6. LLMOps
# 7. Miscellaneous
#
#
# ### Do we need to learn both?
#
# Builder Side --> Data Scientist
#
# User Side --> Software Developers
#
# Both Side --> AI Engineer
